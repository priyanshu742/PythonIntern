# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu742/PythonIntern/blob/main/MissingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({
    'A':[1,2,np.nan],
    'B':[5,np.nan,np.nan],
    'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.describe()
# Out:
#               A    B    C
# count  2.000000  1.0  3.0
# mean   1.500000  5.0  2.0
# std    0.707107  NaN  1.0
# min    1.000000  5.0  1.0
# 25%    1.250000  5.0  1.5
# 50%    1.500000  5.0  2.0
# 75%    1.750000  5.0  2.5
# max    2.000000  5.0  3.0

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.dropna(thresh=1)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value=5)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  5.0  5.0  3
