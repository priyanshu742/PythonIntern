# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu742/PythonIntern/blob/main/NumpyPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=["A","B","C"])
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series([sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
s1=pd.Series([sum,print,len])
s1
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
s1[0]([1,2])
# Out:
# 3

# %%
ser1=pd.Series(data=[1,2,3,4],index=['USA','Germany','USSR','Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2=pd.Series(data=[1,2,5,4],index=['USA','Germany','Italy','Japan'])
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# np.int64(1)

# %%
ser1+ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser1-ser2
# Out:
# Germany    0.0
# Italy      NaN
# Japan      0.0
# USA        0.0
# USSR       NaN
# dtype: float64

# %%
ser1*2
# Out:
# USA        2
# Germany    4
# USSR       6
# Japan      8
# dtype: int64
